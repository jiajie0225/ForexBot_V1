# %%
import pandas as pd
import plotly.graph_objects as go
import datetime as dt

# %%
pair = "EUR_USD"
granularity ="H4"
df = pd.read_pickle(f"../data/{pair}_{granularity}.pkl")

# %%
df.tail()
# Out:
#                           time  volume    mid_o    mid_h    mid_l    mid_c  \
# 3995 2023-11-16 02:00:00+00:00    7543  1.08438  1.08441  1.08302  1.08380
# 3996 2023-11-16 06:00:00+00:00   14123  1.08382  1.08610  1.08341  1.08510
# 3997 2023-11-16 10:00:00+00:00   17665  1.08510  1.08816  1.08390  1.08810
# 3998 2023-11-16 14:00:00+00:00   26976  1.08809  1.08956  1.08465  1.08600
# 3999 2023-11-16 18:00:00+00:00    9096  1.08600  1.08658  1.08448  1.08528
#
#         bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c
# 3995  1.08430  1.08434  1.08295  1.08373  1.08445  1.08448  1.08310  1.08387
# 3996  1.08374  1.08603  1.08334  1.08502  1.08389  1.08618  1.08348  1.08518
# 3997  1.08502  1.08808  1.08383  1.08803  1.08517  1.08823  1.08398  1.08818
# 3998  1.08802  1.08949  1.08458  1.08593  1.08816  1.08963  1.08472  1.08607
# 3999  1.08592  1.08651  1.08441  1.08521  1.08607  1.08666  1.08455  1.08536

# %%
df['sTime']= [dt.datetime.strftime(x,"s%y-%m-%d %H:%M") for x in df.time]

# %%
df
# Out:
#                           time  volume    mid_o    mid_h    mid_l    mid_c  \
# 0    2021-04-27 05:00:00+00:00   12507  1.20729  1.20804  1.20574  1.20584
# 1    2021-04-27 09:00:00+00:00   16027  1.20584  1.20926  1.20569  1.20818
# 2    2021-04-27 13:00:00+00:00   18665  1.20817  1.20904  1.20692  1.20709
# 3    2021-04-27 17:00:00+00:00    8266  1.20710  1.20930  1.20706  1.20916
# 4    2021-04-27 21:00:00+00:00    2659  1.20898  1.20930  1.20782  1.20786
# ...                        ...     ...      ...      ...      ...      ...
# 3995 2023-11-16 02:00:00+00:00    7543  1.08438  1.08441  1.08302  1.08380
# 3996 2023-11-16 06:00:00+00:00   14123  1.08382  1.08610  1.08341  1.08510
# 3997 2023-11-16 10:00:00+00:00   17665  1.08510  1.08816  1.08390  1.08810
# 3998 2023-11-16 14:00:00+00:00   26976  1.08809  1.08956  1.08465  1.08600
# 3999 2023-11-16 18:00:00+00:00    9096  1.08600  1.08658  1.08448  1.08528
#
#         bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c  \
# 0     1.20722  1.20797  1.20568  1.20579  1.20736  1.20811  1.20580  1.20590
# 1     1.20577  1.20920  1.20563  1.20812  1.20590  1.20934  1.20575  1.20824
# 2     1.20812  1.20898  1.20686  1.20703  1.20822  1.20910  1.20698  1.20715
# 3     1.20704  1.20922  1.20700  1.20907  1.20716  1.20938  1.20712  1.20926
# 4     1.20883  1.20920  1.20776  1.20780  1.20913  1.20943  1.20789  1.20793
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 3995  1.08430  1.08434  1.08295  1.08373  1.08445  1.08448  1.08310  1.08387
# 3996  1.08374  1.08603  1.08334  1.08502  1.08389  1.08618  1.08348  1.08518
# 3997  1.08502  1.08808  1.08383  1.08803  1.08517  1.08823  1.08398  1.08818
# 3998  1.08802  1.08949  1.08458  1.08593  1.08816  1.08963  1.08472  1.08607
# 3999  1.08592  1.08651  1.08441  1.08521  1.08607  1.08666  1.08455  1.08536
#
#                 sTime
# 0     s21-04-27 05:00
# 1     s21-04-27 09:00
# 2     s21-04-27 13:00
# 3     s21-04-27 17:00
# 4     s21-04-27 21:00
# ...               ...
# 3995  s23-11-16 02:00
# 3996  s23-11-16 06:00
# 3997  s23-11-16 10:00
# 3998  s23-11-16 14:00
# 3999  s23-11-16 18:00
#
# [4000 rows x 15 columns]

# %%
df_plot= df.iloc[:100]

# %%
df_plot
# Out:
#                         time  volume    mid_o    mid_h    mid_l    mid_c  \
# 0  2021-04-27 05:00:00+00:00   12507  1.20729  1.20804  1.20574  1.20584
# 1  2021-04-27 09:00:00+00:00   16027  1.20584  1.20926  1.20569  1.20818
# 2  2021-04-27 13:00:00+00:00   18665  1.20817  1.20904  1.20692  1.20709
# 3  2021-04-27 17:00:00+00:00    8266  1.20710  1.20930  1.20706  1.20916
# 4  2021-04-27 21:00:00+00:00    2659  1.20898  1.20930  1.20782  1.20786
# ..                       ...     ...      ...      ...      ...      ...
# 95 2021-05-19 01:00:00+00:00    6935  1.22265  1.22354  1.22174  1.22314
# 96 2021-05-19 05:00:00+00:00   20061  1.22312  1.22454  1.22045  1.22165
# 97 2021-05-19 09:00:00+00:00   22905  1.22167  1.22207  1.21888  1.22078
# 98 2021-05-19 13:00:00+00:00   35434  1.22079  1.22388  1.22036  1.22110
# 99 2021-05-19 17:00:00+00:00   33059  1.22108  1.22149  1.21597  1.21758
#
#       bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c  \
# 0   1.20722  1.20797  1.20568  1.20579  1.20736  1.20811  1.20580  1.20590
# 1   1.20577  1.20920  1.20563  1.20812  1.20590  1.20934  1.20575  1.20824
# 2   1.20812  1.20898  1.20686  1.20703  1.20822  1.20910  1.20698  1.20715
# 3   1.20704  1.20922  1.20700  1.20907  1.20716  1.20938  1.20712  1.20926
# 4   1.20883  1.20920  1.20776  1.20780  1.20913  1.20943  1.20789  1.20793
# ..      ...      ...      ...      ...      ...      ...      ...      ...
# 95  1.22258  1.22347  1.22166  1.22306  1.22272  1.22361  1.22181  1.22321
# 96  1.22305  1.22448  1.22038  1.22158  1.22318  1.22461  1.22052  1.22172
# 97  1.22160  1.22200  1.21882  1.22071  1.22174  1.22214  1.21895  1.22085
# 98  1.22072  1.22381  1.22030  1.22103  1.22086  1.22395  1.22043  1.22116
# 99  1.22103  1.22142  1.21590  1.21751  1.22113  1.22156  1.21604  1.21765
#
#               sTime
# 0   s21-04-27 05:00
# 1   s21-04-27 09:00
# 2   s21-04-27 13:00
# 3   s21-04-27 17:00
# 4   s21-04-27 21:00
# ..              ...
# 95  s21-05-19 01:00
# 96  s21-05-19 05:00
# 97  s21-05-19 09:00
# 98  s21-05-19 13:00
# 99  s21-05-19 17:00
#
# [100 rows x 15 columns]

# %%
fig= go.Figure()
fig.add_trace(go.Candlestick(
    x= df_plot.sTime,
    open = df_plot.mid_o,
    high = df_plot.mid_h,
    low = df_plot.mid_l,
    close = df_plot.mid_c,
    line=dict(width=1), opacity=1,
    increasing_fillcolor='#24A06B',
    decreasing_fillcolor="#CC2E3C",
    increasing_line_color='#2EC886',  
    decreasing_line_color='#FF3A4C'
))
fig.update_xaxes(
    gridcolor="#1f292f",
    showgrid=True,fixedrange=True,rangeslider=dict(visible=False),
    nticks=5
)
fig.update_yaxes(
    gridcolor="#1f292f",
    showgrid=True
)

fig.update_layout(
    width = 1500,
    height = 500,
    margin = dict(l=10, r=10, b=10, t=10),
    paper_bgcolor="#1e1e1e",
    plot_bgcolor="#1e1e1e",
    font=dict(size=10,color="#e1e1e1"),

)




fig.show()
